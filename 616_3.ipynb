# %%
#V vs t when z=0
import matplotlib.pyplot as plt
plt.plot([0,2,2,4,4,6,6,8],[36,36,57.6,57.6,59.76,59.76,59.976,59.976])
plt.text(1,36,'36V')
plt.text(3, 57.6, '57.6V')
plt.text(5, 59.76, '59.76V')
plt.text(7, 59.976, '59.976V')
plt.ylabel("V")
plt.xlabel("t in microseconds")
plt.show()

# %%
#I vs t when z=0

import matplotlib.pyplot as plt
plt.plot([0,2,2,4,4,6,6,8],[0.6,0.6,0.36,.36,0.336,0.336,0.334,0.334])
plt.text(1,0.6,'0.6A')
plt.text(3, 0.36, '0.36A')
plt.text(5, 0.336, '0.336A')
plt.text(7, 0.334, '0.334A')
plt.ylabel("I - current")
plt.xlabel("t in microseconds")
plt.show()

# %%
#V vs t when z=l
import matplotlib.pyplot as plt
plt.plot([1,3,3,5,5,7],[54,54,59.4,59.4,59.94,59.94])
plt.text(2,54,'54V')
plt.text(4, 59.4, '59.4V')
plt.text(6, 59.94, '59.94V')
plt.ylabel("V")
plt.xlabel("t in microseconds")
plt.show()

# %%
#I vs t when z=l

import matplotlib.pyplot as plt
plt.plot([1,3,3,5,5,7],[0.3,0.3,0.33,.33,0.333,0.333])
plt.text(2,0.3,'0.3A')
plt.text(4, 0.33, '0.33A')
plt.text(6, 0.333, '0.333A')
plt.ylabel("I - current")
plt.xlabel("t in microseconds")
plt.show()

# %%
#V vs t when z=l/2
import matplotlib.pyplot as plt
plt.plot([0.5,1.5,1.5,2.5,2.5,3.5,3.5,4.5,4.5,5.5,5.5,6.5],[36,36,54,54,57.6,57.6,59.4,59.4,59.76,59.76,59.94,59.94])
plt.text(1,36,'36V')
plt.text(2, 54, '54V')
plt.text(3, 57.6, '57.6V')
plt.text(4, 59.4, '59.4V')
plt.text(5, 59.76, '59.76V')
plt.text(6, 59.94, '59.94V')

plt.ylabel("V  - voltage")
plt.xlabel("t in microseconds")
plt.show()

# %%
#I vs t when z=l/2

import matplotlib.pyplot as plt
plt.plot([0.5,1.5,1.5,2.5,2.5,3.5,3.5,4.5,4.5,5.5,5.5,6.5],[.6,.6,.3,.3,0.36,.36,0.33,0.33,0.333,.333,0.334,0.334])
plt.text(1,0.6,'0.6A')
plt.text(2, 0.3, '0.3A')
plt.text(3, 0.36, '0.36A')
plt.text(4, 0.33, '0.33A')
plt.text(5, 0.336, '0.336A')
plt.text(6, 0.333, '0.333A')

plt.ylabel("I - current")
plt.xlabel("t in microseconds")
plt.show()

# %%
#V vs z when t=1.2microseconds
import matplotlib.pyplot as plt
plt.plot([0,.8,.8,1.1],[36,36,54,54])
plt.text(.5,36,'36V')
plt.text(.9, 54, '54V')
plt.ylabel("V")
plt.xlabel("z")
plt.show()

# %%
##I vs z when t=1.2microseconds
import matplotlib.pyplot as plt
plt.plot([0,.8,.8,1.1],[.6,.6,.3,.3])
plt.text(.5,.6,'0.6A')
plt.text(.9, .3, '0.3A')
plt.ylabel("V")
plt.xlabel("z")
plt.ylabel("I - current")
plt.xlabel("z")
plt.show()

# %%
#V vs z when t=3.5microseconds
import matplotlib.pyplot as plt
plt.plot([0,.5,.5,1.0],[57.6,57.6,59.4,59.4])
plt.text(.25,57.6,'57.6V')
plt.text(.6, 59.4, '59.4V')
plt.ylabel("V")
plt.xlabel("z")
plt.show()

# %%
##I vs z when t=1.2microseconds
import matplotlib.pyplot as plt
plt.plot([0,0.5,0.5,1],[0.36,0.36,0.33,0.33])
plt.text(0.25,0.36,'0.36A')
plt.text(0.75, 0.33, '0.33A')
plt.ylabel("I")
plt.xlabel("z")
plt.ylabel("I - current")
plt.xlabel("z")
plt.show()
